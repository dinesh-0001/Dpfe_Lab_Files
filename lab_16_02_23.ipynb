# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\Dinesh\OneDrive\Documents\4th_Sem_Lab\Data_Preprocess_Lab\billionaire\billionaire1.csv')

# %%
df
# Out:
#         Unnamed: 0                          name   last_name  age gender  \
# 0              675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 1              676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 2              677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 3              678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 4              679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# ...            ...                           ...         ...  ...    ...
# 352364      358313            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352365      358314            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352366      358315            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352367      358316            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352368      358317            Zygmunt Solorz-Zak  Solorz-Zak   65      M
#
#         time           permanent_country         company  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1=df.isnull()

# %%
df1
# Out:
#         Unnamed: 0   name  last_name    age  gender   time  permanent_country  \
# 0            False  False      False  False   False  False              False
# 1            False  False      False  False   False  False              False
# 2            False  False      False  False   False  False              False
# 3            False  False      False  False   False  False              False
# 4            False  False      False  False   False  False              False
# ...            ...    ...        ...    ...     ...    ...                ...
# 352364       False  False      False  False   False  False              False
# 352365       False  False      False  False   False  False              False
# 352366       False  False      False  False   False  False              False
# 352367       False  False      False  False   False  False              False
# 352368       False  False      False  False   False  False              False
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# name                          0
# last_name                 10850
# age                           0
# gender                    11892
# time                          0
# permanent_country         47691
# company                   25500
# main_industry                 0
# wealth_source_details     10922
# industry                     49
# state                    193179
# headquarters             218714
# countries                     0
# annual_income                 0
# daily_income                  0
# birth_year                    0
# name_cleaned                  0
# dtype: int64

# %%
df[['main_industry','industry']]
# Out:
#                 main_industry  \
# 0                 Diversified
# 1                 Diversified
# 2                 Diversified
# 3                 Diversified
# 4                 Diversified
# ...                       ...
# 352364  Media & Entertainment
# 352365  Media & Entertainment
# 352366  Media & Entertainment
# 352367  Media & Entertainment
# 352368  Media & Entertainment
#
#                                                 industry
# 0                                    Diversified;Banking
# 1                                    Diversified;Banking
# 2                                    Diversified;Banking
# 3                                    Diversified;Banking
# 4                                    Diversified;Banking
# ...                                                  ...
# 352364  Media & Entertainment; Media;Media;Entertainment
# 352365  Media & Entertainment; Media;Media;Entertainment
# 352366  Media & Entertainment; Media;Media;Entertainment
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                          name   last_name  age gender  time  \
# 0         675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 1         676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 2         677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 3         678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 4         679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
#
#             permanent_country       company main_industry  \
# 0  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 1  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 2  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 3  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 4  United Arab Emirates-Dubai  Mashreq Bank   Diversified
#
#   wealth_source_details             industry state headquarters countries  \
# 0           diversified  Diversified;Banking   NaN          NaN       are
# ...

# %%
print(df['main_industry'])
# Out:
# 0                   Diversified
# 1                   Diversified
# 2                   Diversified
# 3                   Diversified
# 4                   Diversified
#                   ...
# 352364    Media & Entertainment
# 352365    Media & Entertainment
# 352366    Media & Entertainment
# 352367    Media & Entertainment
# 352368    Media & Entertainment
# Name: main_industry, Length: 352369, dtype: object

# %%
df['main_industry'].unique()
# Out:
# array(['Diversified', 'Estate Holding', 'Pharmaceuticals',
#        'Consumer Electronics', 'Food & Beverage', 'Retail',
#        'Divorce Settlement', 'Dairy Products', 'Multi-Brand Retail',
#        'Cement', 'Food Processing', 'Investments', 'Fashion & Retail',
#        'Energy Drink', 'Industrial Products', 'Finance & Investments',
#        'Automotive', 'Sports', 'Advertising', 'Media', 'Eye Wear',
#        'Publishing', 'Aviation', 'TMT', 'Transportation',
#        'Automobiles & Components', 'Telecommunications', 'Diamonds',
#        'Cargo pumps', 'Water and recycling management', 'Real Estate',
#        'Metals & Mining', 'Jewellery、 Estate Holding', 'Healthcare',
#        'Electronics', 'Oil & Gas', 'Automobile', 'Commodities',
#        'Manufacturing', 'Logistics', 'Media Services', 'Technology',
#        'Biotechnology', 'Machinery', 'Apparel & Textile Products',
#        'Household Appliances', 'Financial Services', 'Beverages',
# ...

# %%
df['main_industry'].nunique()
# Out:
# 190

# %%
df2=df.fillna(100)

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0               0
# name                     0
# last_name                0
# age                      0
# gender                   0
# time                     0
# permanent_country        0
# company                  0
# main_industry            0
# wealth_source_details    0
# industry                 0
# state                    0
# headquarters             0
# countries                0
# annual_income            0
# daily_income             0
# birth_year               0
# name_cleaned             0
# dtype: int64

# %%
df2['last_name'].unique()
# Out:
# array(['Al Ghurair', 100, 'Cherng', ..., 'Zong', 'Zuo', 'Solorz-Zak'],
#       dtype=object)

# %%
df3=df.copy()

# %%
df4=df3.dropna()

# %%
df4.head()
# Out:
#       Unnamed: 0                name last_name  age gender  time  \
# 1199      118347  Hank & Doug Meijer    Meijer   69      M  2012
# 1200      118348  Hank & Doug Meijer    Meijer   69      M  2012
# 1201      118349  Hank & Doug Meijer    Meijer   69      M  2012
# 1202      118350  Hank & Doug Meijer    Meijer   69      M  2012
# 1203      118351  Hank & Doug Meijer    Meijer   69      M  2012
#
#                         permanent_country             company  \
# 1199  United States-Michigan-Grand Rapids  Meijer Supermarket
# 1200  United States-Michigan-Grand Rapids  Meijer Supermarket
# 1201  United States-Michigan-Grand Rapids  Meijer Supermarket
# 1202  United States-Michigan-Grand Rapids  Meijer Supermarket
# 1203  United States-Michigan-Grand Rapids  Meijer Supermarket
#
#          main_industry wealth_source_details  \
# 1199  Fashion & Retail          supermarkets
# 1200  Fashion & Retail          supermarkets
# 1201  Fashion & Retail          supermarkets
# ...

# %%
df.dropna(axis=1)
# Out:
#         Unnamed: 0                          name  age  time  \
# 0              675  Abdulla bin Ahmad Al Ghurair   67  2013
# 1              676  Abdulla bin Ahmad Al Ghurair   67  2013
# 2              677  Abdulla bin Ahmad Al Ghurair   67  2013
# 3              678  Abdulla bin Ahmad Al Ghurair   67  2013
# 4              679  Abdulla bin Ahmad Al Ghurair   67  2013
# ...            ...                           ...  ...   ...
# 352364      358313            Zygmunt Solorz-Zak   65  2022
# 352365      358314            Zygmunt Solorz-Zak   65  2022
# 352366      358315            Zygmunt Solorz-Zak   65  2022
# 352367      358316            Zygmunt Solorz-Zak   65  2022
# 352368      358317            Zygmunt Solorz-Zak   65  2022
#
#                 main_industry countries  annual_income  daily_income  \
# 0                 Diversified       are       95604000        261928
# 1                 Diversified       are       95604000        399254
# ...

# %%
df.dropna(thresh=17)
# Out:
#         Unnamed: 0                   name last_name  age gender  time  \
# 197          21325  Andrew & Peggy Cherng    Cherng   74      F  2013
# 198          21326  Andrew & Peggy Cherng    Cherng   74      F  2013
# 199          21327  Andrew & Peggy Cherng    Cherng   74      F  2013
# 200          21328  Andrew & Peggy Cherng    Cherng   74      F  2013
# 201          21329  Andrew & Peggy Cherng    Cherng   74      F  2013
# ...            ...                    ...       ...  ...    ...   ...
# 351978      357926           Zong Qinghou      Zong   76      M  2022
# 351979      357927           Zong Qinghou      Zong   76      M  2022
# 351980      357928           Zong Qinghou      Zong   76      M  2022
# 351981      357929           Zong Qinghou      Zong   76      M  2022
# 351984      357933               Zugen Ni        Ni   65      M  2022
#
#               permanent_country             company    main_industry  \
# ...

# %%
df.fillna(value=1000)
# Out:
#         Unnamed: 0                          name   last_name  age gender  \
# 0              675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 1              676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 2              677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 3              678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 4              679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# ...            ...                           ...         ...  ...    ...
# 352364      358313            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352365      358314            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352366      358315            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352367      358316            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352368      358317            Zygmunt Solorz-Zak  Solorz-Zak   65      M
#
#         time           permanent_country         company  \
# ...

# %%
df['age']=df['age'].fillna(value=55)

# %%
df['age']
# Out:
# 0         67
# 1         67
# 2         67
# 3         67
# 4         67
#           ..
# 352364    65
# 352365    65
# 352366    65
# 352367    65
# 352368    65
# Name: age, Length: 352369, dtype: int64

# %%
df['age'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# name                          0
# last_name                 10850
# age                           0
# gender                    11892
# time                          0
# permanent_country         47691
# company                   25500
# main_industry                 0
# wealth_source_details     10922
# industry                     49
# state                    193179
# headquarters             218714
# countries                     0
# annual_income                 0
# daily_income                  0
# birth_year                    0
# name_cleaned                  0
# dtype: int64

# %%
m=df['gender'].mode()

# %%
m
# Out:
# 0    M
# Name: gender, dtype: object

# %%
df4=df.copy()
['gender'].fillna(value=m)

# %%
df4.gender.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7288\3071180339.py in <module>
# ----> 1 df4.gender.unique()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'gender'
